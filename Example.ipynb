# %% [markdown]
# ### Basic Libraries
# ##### NLTK

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')

# %%
text="Natural Language Processing is amazing!"
tokens=word_tokenize(text)
print(tokens)
# Out:
# ['Natural', 'Language', 'Processing', 'is', 'amazing', '!']

# %% [markdown]
# ##### spacy

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
import spacy
nlp=spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: spacy in /home/ds-lab/anaconda3/lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: setuptools in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Requirement already satisfied: jinja2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: packaging>=20.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (24.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (2.10.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 63.6 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
text="Elon Musk founded SpaceX in 2002."
doc=nlp(text)
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Elon Musk PERSON
# 2002 DATE

# %% [markdown]
# ##### TextBlob

# %%
# !pip install textblob
from textblob import TextBlob
text="I love Python. It is so powerful!"
blob=TextBlob(text)
print(blob.sentiment)
# Out:
# Requirement already satisfied: textblob in /home/ds-lab/anaconda3/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: tqdm in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: joblib in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from nltk>=3.9->textblob) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from nltk>=3.9->textblob) (2022.7.9)
# Requirement already satisfied: click in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from nltk>=3.9->textblob) (8.2.1)
# Sentiment(polarity=0.4375, subjectivity=0.8)

# %% [markdown]
# ##### scikit-learn

# %%
# !pip install scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
corpus=["NLP is amazing","I love learning NLP"]
vectorizer=TfidfVectorizer()
X=vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# Requirement already satisfied: scikit-learn in /home/ds-lab/anaconda3/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from scikit-learn) (1.1.1)
# ['amazing' 'is' 'learning' 'love' 'nlp']
# [[0.6316672  0.6316672  0.         0.         0.44943642]
#  [0.         0.         0.6316672  0.6316672  0.44943642]]

# %% [markdown]
# ##### Transformers(Hugging Face)

# %%
# !pip install transformers
from transformers import pipeline
generator=pipeline("text-generation")
print(generator("Artificial Intelligence is", max_length=30))
# Out:
# Requirement already satisfied: transformers in /home/ds-lab/anaconda3/lib/python3.10/site-packages (4.55.0)
# Requirement already satisfied: filelock in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (0.34.4)
# Requirement already satisfied: packaging>=20.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: requests in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: numpy>=1.17 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: tqdm>=4.27 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Disabling PyTorch because PyTorch >= 2.1 is required but found 1.12.1
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 get_ipython().system('pip install transformers')
#       2 from transformers import pipeline
# ----> 3 generator=pipeline("text-generation")
#       4 print(generator("Artificial Intelligence is", max_length=30))
#
# File ~/anaconda3/lib/python3.10/site-packages/transformers/pipelines/__init__.py:998, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     993         raise ValueError(
#     994             'You cannot use both `pipeline(... torch_dtype=..., model_kwargs={"torch_dtype":...})` as those'
#     995             " arguments might conflict, use only one.)"
#     996         )
#     997 if torch_dtype is not None:
# --> 998     if isinstance(torch_dtype, str) and hasattr(torch, torch_dtype):
#     999         torch_dtype = getattr(torch, torch_dtype)
#    1000     model_kwargs["torch_dtype"] = torch_dtype
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ##### Gensim

# %%
# !pip install gensim
from gensim.models import Word2Vec
sentences=[["hello","world"],["machine","learning"],["deep","learning"]]
model=Word2Vec(sentences,min_count=1)
print(model.wv.most_similar("learning"))
# Out:
# Requirement already satisfied: gensim in /home/ds-lab/anaconda3/lib/python3.10/site-packages (4.3.0)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from gensim) (2.0.9)
# Requirement already satisfied: scipy>=1.7.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: pyfume in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from FuzzyTM>=0.4.0->gensim) (0.3.4)
# Requirement already satisfied: pandas in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from FuzzyTM>=0.4.0->gensim) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.7)
# Requirement already satisfied: simpful==2.12.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.12.0)
# Collecting numpy>=1.18.5
#   Using cached numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied: fst-pso==1.8.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: miniful in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from fst-pso==1.8.1->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: six>=1.5 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.4 which is incompatible.
# langchain-community 0.3.27 requires numpy>=1.26.2; python_version < "3.13", but you have numpy 1.24.4 which is incompatible.
# faiss-cpu 1.11.0.post1 requires numpy<3.0,>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# Successfully installed numpy-1.24.4
# [('deep', -0.01083916611969471), ('hello', -0.02775035798549652), ('machine', -0.05234673246741295), ('world', -0.111670583486557)]
