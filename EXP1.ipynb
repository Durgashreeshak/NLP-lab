# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re
# Out:
# Requirement already satisfied: nltk in /home/ds-lab/anaconda3/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: joblib in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from nltk) (1.1.1)
# Requirement already satisfied: tqdm in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: click in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from nltk) (8.2.1)

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/ds-lab/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/ds-lab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)
    print("Tokenized Words:", tokens)
    
    filtered_tokens = [word for word in tokens if word.isalnum()]
    print("Filtered Tokens:", filtered_tokens)

    validated_tokens = [word for word in filtered_tokens if re.match("^[A-Za-z]+$", word)]
    print("Script Validated Tokens:", validated_tokens)
    
  
    stop_words = set(stopwords.words('english'))
    tokens_without_stopwords = [word for word in validated_tokens if word.lower() not in stop_words]
    print("After Stop Word Removal:", tokens_without_stopwords)

    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(word) for word in tokens_without_stopwords]
    print("After Stemming:", stemmed_tokens)
    
    return stemmed_tokens

text = "Natural Language Processing(NLP) is a facinating field of Artificial Intelligence!"
preprocess_text(text)
# Out:
# Tokenized Words: ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'facinating', 'field', 'of', 'Artificial', 'Intelligence', '!']
# Filtered Tokens: ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'facinating', 'field', 'of', 'Artificial', 'Intelligence']
# Script Validated Tokens: ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'facinating', 'field', 'of', 'Artificial', 'Intelligence']
# After Stop Word Removal: ['Natural', 'Language', 'Processing', 'NLP', 'facinating', 'field', 'Artificial', 'Intelligence']
# After Stemming: ['natur', 'languag', 'process', 'nlp', 'facin', 'field', 'artifici', 'intellig']
# ['natur',
#  'languag',
#  'process',
#  'nlp',
#  'facin',
#  'field',
#  'artifici',
#  'intellig']

# %%
# !pip install langdetect
from langdetect import detect
text="नमस्ते, आप कैसे हैं?"
lang=detect(text)
print(f"The language of the text is:{lang}")
# Out:
# Requirement already satisfied: langdetect in /home/ds-lab/anaconda3/lib/python3.10/site-packages (1.0.9)
# Requirement already satisfied: six in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from langdetect) (1.16.0)
# The language of the text is:hi
